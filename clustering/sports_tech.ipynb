# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('sports_tech.csv')

# %%
df.head()
# Out:
#    ID                                           Sentence Category
# 0   1  New advancements in Data Science improve effic...   Sports
# 1   2                          AI is changing the future   Sports
# 2   3           Quantum Computing is changing the future   Sports
# 3   4                  Athletes train daily for swimming   Sports
# 4   5                  Athletes train daily for swimming   Sports

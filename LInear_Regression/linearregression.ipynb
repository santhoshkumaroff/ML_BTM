# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot  as plt
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error



df = pd.DataFrame({'Study_Hours':list(range(1,11)),'Exam_score':list(range(10,101,10))})
df
# Out:
#    Study_Hours  Exam_score
# 0            1          10
# 1            2          20
# 2            3          30
# 3            4          40
# 4            5          50
# 5            6          60
# 6            7          70
# 7            8          80
# 8            9          90
# 9           10         100

# %%
x=df[['Study_Hours']]
y=df['Exam_score']

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# train_test_split(x,y,train_size=0.8,random_state=40)

# %%
#model creation
model = LinearRegression()

# %%
#fit or train the model

model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(-7.105427357601002e-15)

# %%
model.coef_
# Out:
# array([10.])

# %%
xtest
# Out:
#    Study_Hours
# 8            9
# 1            2

# %%
ypred= model.predict(xtest)

# %%
plt.scatter(xtest,ytest)
plt.scatter(xtest,ypred)

# %%
r2_score(ytest,ypred)
# Out:
# 1.0

# %%
model.score(xtest,ytest)
# Out:
# 1.0

# %%
mean_squared_error(ytest,ypred)
# Out:
# 6.310887241768095e-30

# %%
mean_absolute_error(ytest,ypred)
# Out:
# 1.7763568394002505e-15

# %%
newdata=pd.DataFrame({'Study_Hours':[10,5]})
# newdata = [[10],[5]]
model.predict(newdata)
# Out:
# array([100.,  50.])

# %%
xtrain
# Out:
#    Study_Hours
# 5            6
# 0            1
# 7            8
# 2            3
# 9           10
# 4            5
# 3            4
# 6            7

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

scalar = StandardScaler()
xscaled = scalar.fit_transform(df)
xscaled
# Out:
# array([[-1.67524673, -1.51005294, -1.36011263],
#        [-1.55971247, -1.43837321, -1.10552744],
#        [-1.44417822, -1.36669348, -1.419919  ],
#        [-1.32864396, -1.18749416, -1.20495739],
#        [-1.2131097 , -1.11581443, -1.33978143],
#        [-1.09757545, -0.86493538, -0.71830716],
#        [-0.98204119, -0.82909552, -0.58815781],
#        [-0.86650693, -0.75741579, -0.79981746],
#        [-0.75097267, -0.75741579, -0.42881019],
#        [-0.63543842, -0.57821647, -0.69801306],
#        [-0.51990416, -0.50653674, -0.47433279],
#        [-0.4043699 , -0.47069688, -0.74976858],
#        [-0.28883564, -0.47069688, -0.70662043],
#        [-0.17330139, -0.43485702, -0.70201994],
#        [-0.05776713, -0.29149756, -0.55250402],
#        [ 0.05776713, -0.1481381 , -0.29921736],
#        [ 0.17330139, -0.07645838, -0.37004264],
#        [ 0.28883564, -0.00477865,  0.26285865],
#        [ 0.4043699 ,  0.21026054,  0.19885989],
#        [ 0.51990416,  0.2461004 ,  0.66547573],
# ...

# %%
np.mean(xscaled[:,2])
# Out:
# np.float64(1.4802973661668754e-17)

# %%
np.std(xscaled[:,0])
# Out:
# np.float64(1.0)
